# %%
conda install statsmodel
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - statsmodel
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge statsmodels
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.5.2
#   latest version: 23.7.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.7.3
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/will/anaconda3/envs/envWillThesis
#
#   added / updated specs:
#     - statsmodels
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.7.22  |       h8857fd0_0         146 KB  conda-forge
#     certifi-2023.7.22          |     pyhd8ed1ab_0         150 KB  conda-forge
#     notebook-6.3.0             |   py38h50d1736_0         6.3 MB  conda-forge
#     openssl-1.1.1v             |       h8a1eda9_0         1.7 MB  conda-forge
#     patsy-0.5.3                |     pyhd8ed1ab_0         189 KB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     statsmodels-0.14.0         |   py38hd2faf92_1         9.7 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        18.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   patsy              conda-forge/noarch::patsy-0.5.3-pyhd8ed1ab_0
#   python_abi         conda-forge/osx-64::python_abi-3.8-2_cp38
#   statsmodels        conda-forge/osx-64::statsmodels-0.14.0-py38hd2faf92_1
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.05.30~ --> conda-forge::ca-certificates-2023.7.22-h8857fd0_0
#   certifi            pkgs/main/osx-64::certifi-2023.5.7-py~ --> conda-forge/noarch::certifi-2023.7.22-pyhd8ed1ab_0
#   openssl              pkgs/main::openssl-1.1.1u-hca72f7f_0 --> conda-forge::openssl-1.1.1v-h8a1eda9_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   notebook           pkgs/main::notebook-6.5.4-py38hecd8cb~ --> conda-forge::notebook-6.3.0-py38h50d1736_0
#
#
#
# Downloading and Extracting Packages
# python_abi-3.8       | 4 KB      |                                       |   0%
# notebook-6.3.0       | 6.3 MB    |                                       |   0%
#
# ca-certificates-2023 | 146 KB    |                                       |   0%
#
#
# patsy-0.5.3          | 189 KB    |                                       |   0%
#
#
#
# certifi-2023.7.22    | 150 KB    |                                       |   0%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    |                                       |   0%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    |                                       |   0%
#
# ca-certificates-2023 | 146 KB    | ####                                  |  11%
#
#
# patsy-0.5.3          | 189 KB    | ###1                                  |   8%
#
# ca-certificates-2023 | 146 KB    | ############1                         |  33%
# notebook-6.3.0       | 6.3 MB    |                                       |   0%
#
# ca-certificates-2023 | 146 KB    | ################################3     |  87%
#
#
#
# certifi-2023.7.22    | 150 KB    | ###9                                  |  11%
#
#
# patsy-0.5.3          | 189 KB    | ############5                         |  34%
#
# ca-certificates-2023 | 146 KB    | ##################################### | 100%
# notebook-6.3.0       | 6.3 MB    | 5                                     |   1%
#
#
# patsy-0.5.3          | 189 KB    | ##################################### | 100%
#
#
#
# certifi-2023.7.22    | 150 KB    | ###########################5          |  75%
#
#
#
# python_abi-3.8       | 4 KB      | ##################################### | 100%
# notebook-6.3.0       | 6.3 MB    | 9                                     |   2%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | 3                                     |   1%
# notebook-6.3.0       | 6.3 MB    | #1                                    |   3%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    |                                       |   0%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | #3                                    |   4%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | 1                                     |   0%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | ##7                                   |   8%
# notebook-6.3.0       | 6.3 MB    | #4                                    |   4%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | 6                                     |   2%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | ########                              |  22%
# notebook-6.3.0       | 6.3 MB    | ##5                                   |   7%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #                                     |   3%
# notebook-6.3.0       | 6.3 MB    | ##9                                   |   8%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #2                                    |   3%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | ##########4                           |  28%
# notebook-6.3.0       | 6.3 MB    | ###3                                  |   9%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | ############2                         |  33%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #5                                    |   4%
# notebook-6.3.0       | 6.3 MB    | ####2                                 |  11%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | ##############3                       |  39%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #9                                    |   5%
# notebook-6.3.0       | 6.3 MB    | ####6                                 |  13%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ##1                                   |   6%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | ################                      |  43%
# notebook-6.3.0       | 6.3 MB    | #####                                 |  14%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | #################4                    |  47%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ##3                                   |   6%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | ###################9                  |  54%
# notebook-6.3.0       | 6.3 MB    | #####4                                |  15%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ##9                                   |   8%
# notebook-6.3.0       | 6.3 MB    | #####9                                |  16%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | #####################6                |  59%
# notebook-6.3.0       | 6.3 MB    | ######3                               |  17%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ###2                                  |   9%
# notebook-6.3.0       | 6.3 MB    | ######6                               |  18%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | #######################               |  62%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ###5                                  |   9%
# notebook-6.3.0       | 6.3 MB    | #######1                              |  19%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | ##########################5           |  72%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ###8                                  |  10%
# notebook-6.3.0       | 6.3 MB    | #######5                              |  20%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ####1                                 |  11%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | ############################3         |  77%
# notebook-6.3.0       | 6.3 MB    | #######8                              |  21%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ####4                                 |  12%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | #############################7        |  80%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | ###############################1      |  84%
# notebook-6.3.0       | 6.3 MB    | ########1                             |  22%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ####6                                 |  13%
# notebook-6.3.0       | 6.3 MB    | ########6                             |  23%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ####8                                 |  13%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | ################################5     |  88%
# notebook-6.3.0       | 6.3 MB    | #########                             |  25%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #####2                                |  14%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | ##################################6   |  94%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | ####################################  |  97%
# notebook-6.3.0       | 6.3 MB    | #########4                            |  26%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #####4                                |  15%
#
#
#
#
#
# openssl-1.1.1v       | 1.7 MB    | ##################################### | 100%
# notebook-6.3.0       | 6.3 MB    | ##########2                           |  28%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ######                                |  16%
# notebook-6.3.0       | 6.3 MB    | ##########7                           |  29%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ######3                               |  17%
# notebook-6.3.0       | 6.3 MB    | ###########1                          |  30%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ######6                               |  18%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ######8                               |  19%
# notebook-6.3.0       | 6.3 MB    | ###########6                          |  31%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #######1                              |  19%
# notebook-6.3.0       | 6.3 MB    | ############1                         |  33%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #######4                              |  20%
# notebook-6.3.0       | 6.3 MB    | ############5                         |  34%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #######7                              |  21%
# notebook-6.3.0       | 6.3 MB    | #############                         |  35%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ########                              |  22%
# notebook-6.3.0       | 6.3 MB    | #############4                        |  36%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ########3                             |  23%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ########6                             |  23%
# notebook-6.3.0       | 6.3 MB    | ##############1                       |  38%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #########                             |  25%
# notebook-6.3.0       | 6.3 MB    | ##############8                       |  40%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #########3                            |  25%
# notebook-6.3.0       | 6.3 MB    | ###############3                      |  41%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #########6                            |  26%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #########9                            |  27%
# notebook-6.3.0       | 6.3 MB    | ###############7                      |  43%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ##########2                           |  28%
# notebook-6.3.0       | 6.3 MB    | ################4                     |  44%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ##########5                           |  29%
# notebook-6.3.0       | 6.3 MB    | ################8                     |  46%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ###########1                          |  30%
# notebook-6.3.0       | 6.3 MB    | #################8                    |  48%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ###########5                          |  31%
# notebook-6.3.0       | 6.3 MB    | ##################4                   |  50%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ###########8                          |  32%
# notebook-6.3.0       | 6.3 MB    | ##################9                   |  51%
# notebook-6.3.0       | 6.3 MB    | ###################4                  |  53%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ############1                         |  33%
# notebook-6.3.0       | 6.3 MB    | ####################5                 |  56%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ############7                         |  35%
# notebook-6.3.0       | 6.3 MB    | #####################1                |  57%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #############1                        |  36%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #############4                        |  36%
# notebook-6.3.0       | 6.3 MB    | #####################7                |  59%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #############7                        |  37%
# notebook-6.3.0       | 6.3 MB    | ######################5               |  61%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ##############1                       |  38%
# notebook-6.3.0       | 6.3 MB    | #######################1              |  62%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ##############5                       |  39%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ##############8                       |  40%
# notebook-6.3.0       | 6.3 MB    | #######################5              |  64%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ###############1                      |  41%
# notebook-6.3.0       | 6.3 MB    | ########################3             |  66%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ###############5                      |  42%
# notebook-6.3.0       | 6.3 MB    | #########################3            |  68%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ###############8                      |  43%
# notebook-6.3.0       | 6.3 MB    | #########################9            |  70%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ################1                     |  44%
# notebook-6.3.0       | 6.3 MB    | ##########################5           |  72%
# notebook-6.3.0       | 6.3 MB    | ##########################9           |  73%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ################4                     |  45%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #################                     |  46%
# notebook-6.3.0       | 6.3 MB    | ###########################7          |  75%
# notebook-6.3.0       | 6.3 MB    | ############################6         |  77%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #################4                    |  47%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #################7                    |  48%
# notebook-6.3.0       | 6.3 MB    | #############################2        |  79%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ##################1                   |  49%
# notebook-6.3.0       | 6.3 MB    | #############################8        |  81%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ##################4                   |  50%
# notebook-6.3.0       | 6.3 MB    | ##############################2       |  82%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ##################9                   |  51%
# notebook-6.3.0       | 6.3 MB    | ###############################1      |  84%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ###################2                  |  52%
# notebook-6.3.0       | 6.3 MB    | ###############################7      |  86%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ###################6                  |  53%
# notebook-6.3.0       | 6.3 MB    | ################################2     |  87%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ###################9                  |  54%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ####################2                 |  55%
# notebook-6.3.0       | 6.3 MB    | #################################1    |  90%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ####################8                 |  56%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #####################1                |  57%
# notebook-6.3.0       | 6.3 MB    | #################################5    |  91%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #####################5                |  58%
# notebook-6.3.0       | 6.3 MB    | ##################################    |  92%
# notebook-6.3.0       | 6.3 MB    | ##################################4   |  93%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #####################8                |  59%
# notebook-6.3.0       | 6.3 MB    | ##################################9   |  94%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ######################4               |  61%
# notebook-6.3.0       | 6.3 MB    | ###################################5  |  96%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ######################8               |  62%
# notebook-6.3.0       | 6.3 MB    | ###################################9  |  97%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #######################3              |  63%
# notebook-6.3.0       | 6.3 MB    | ####################################3 |  98%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #######################6              |  64%
# notebook-6.3.0       | 6.3 MB    | ####################################7 |  99%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ########################              |  65%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ########################6             |  67%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #########################             |  68%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #########################6            |  69%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ##########################1           |  71%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ##########################7           |  72%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ###########################2          |  74%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ###########################7          |  75%
# notebook-6.3.0       | 6.3 MB    | ##################################### | 100%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ############################4         |  77%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ############################9         |  78%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #############################4        |  80%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ##############################        |  81%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ##############################5       |  83%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ###############################4      |  85%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ###############################9      |  86%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ################################5     |  88%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | #################################3    |  90%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ##################################    |  92%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ##################################6   |  94%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ###################################3  |  96%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ####################################  |  97%
#
#
#
#
# statsmodels-0.14.0   | 9.7 MB    | ####################################9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm

import pandas as pd

import numpy as np

import matplotlib.pyplot as plt
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
import seaborn as sns  
import statsmodels.api as sm

# %%
# Load our DataFrame 
Offshore_Wind = pd.read_csv('/Users/will/Desktop/Thesis Data/Final ENG Data/CSV_UK_OSW_Final.csv')

# %%
Offshore_Wind.head()
# Out:
#    New_Object_ID           Name_Prop_x  \
# 0              1              Walney 2
# 1              2              Walney 1
# 2              3  West of Duddon Sands
# 3              4                Barrow
# 4              5               Ormonde
#
#                                             Name_Ten      Lease_Stat  \
# 0             Walney (UK) Offshore Windfarms Limited  Lease - Marine
# 1             Walney (UK) Offshore Windfarms Limited  Lease - Marine
# 2  ScottishPower Renewables (WoDS) Limited and Or...  Lease - Marine
# 3                       Barrow Offshore Wind Limited  Lease - Marine
# 4                             Ormonde Energy Limited  Lease - Marine
#
#     Inf_Status  Wind Speed at 100M  Wind Speed at 150M      Region  \
# 0  Operational            9.762180           10.164155  Cumberland
# 1  Operational            9.704449           10.119843  Cumberland
# 2  Operational            9.724218           10.126616  Cumberland
# 3  Operational            9.563191           10.030605  Cumberland
# 4  Operational            9.592508           10.037252  Cumberland
#
#   Commissioning     Foundation Type   Sea Name       Area  Capacity_MW_x  \
# 0    07/12/2021  Grounded: Monopile  Irish Sea  18.716494          183.6
# 1    14/06/2012  Grounded: Monopile  Irish Sea   27.15618          183.6
# 2    30/10/2014  Grounded: Monopile  Irish Sea  66.889246          389.0
# 3    22/09/2006  Grounded: Monopile  Irish Sea   9.990135           90.0
# 4    22/02/2012      Jacket (Piled)  Irish Sea    9.93175          150.0
#
#   Distance from Shore (km) Grid Connection Point  SHAPE_Length  SHAPE_Area_x  \
# 0                       15             Cleveleys      0.333629      0.006297
# 1                       15             Cleveleys      0.278588      0.003724
# 2                       15               Heysham      0.411103      0.009159
# 3                      7.5               Heysham      0.163415      0.001368
# 4                      9.5               Heysham      0.164165      0.001364
#
#                                             geometry  mpa_proximity  \
# 0  POLYGON ((-705942.9946688032 6152116.419927733...            0.0
# 1  POLYGON ((-701457.1220475058 6145627.040104053...            0.0
# 2  POLYGON ((-698911.6075414268 6138268.918918209...            0.0
# 3  POLYGON ((-690771.6241631769 6137881.406813042...            0.0
# 4  POLYGON ((-697020.0412259202 6150781.322604385...            0.0
#
#    mcz_proximity
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3    4615.103852
# 4       0.000000

# %%
num_rows_1 = Offshore_Wind.shape[0]

print("Number of rows:", num_rows_1)
# Out:
# Number of rows: 101

# %%
Offshore_Wind.dtypes
# Out:
# New_Object_ID                 int64
# Name_Prop_x                  object
# Name_Ten                     object
# Lease_Stat                   object
# Inf_Status                   object
# Wind Speed at 100M          float64
# Wind Speed at 150M          float64
# Region                       object
# Commissioning                object
# Foundation Type              object
# Sea Name                     object
# Area                         object
# Capacity_MW_x               float64
# Distance from Shore (km)     object
# Grid Connection Point        object
# SHAPE_Length                float64
# SHAPE_Area_x                float64
# geometry                     object
# mpa_proximity               float64
# mcz_proximity               float64
# dtype: object

# %%
# Create a new DataFrame
Offshore_Wind_new_1 = Offshore_Wind.copy()

# Remove rows with 'N/A' or NaN values from the new DataFrame using dropna
columns_to_check = ['Distance from Shore (km)', 'Area', 'Capacity_MW_x', 'mcz_proximity']
Offshore_Wind_new_1 = Offshore_Wind_new_1.dropna(subset=columns_to_check, how='any', inplace=False)

# Convert selected columns to float in the new DataFrame
columns_to_convert = ['Distance from Shore (km)', 'Area', 'Capacity_MW_x']
for column in columns_to_convert:
    Offshore_Wind_new_1[column] = Offshore_Wind_new_1[column].apply(lambda x: x.replace('.', '', 1) if isinstance(x, str) else x)
    Offshore_Wind_new_1[column] = Offshore_Wind_new_1[column].astype(float)

# %%
Offshore_Wind_new_1.dtypes
# Out:
# New_Object_ID                 int64
# Name_Prop_x                  object
# Name_Ten                     object
# Lease_Stat                   object
# Inf_Status                   object
# Wind Speed at 100M          float64
# Wind Speed at 150M          float64
# Region                       object
# Commissioning                object
# Foundation Type              object
# Sea Name                     object
# Area                        float64
# Capacity_MW_x               float64
# Distance from Shore (km)    float64
# Grid Connection Point        object
# SHAPE_Length                float64
# SHAPE_Area_x                float64
# geometry                     object
# mpa_proximity               float64
# mcz_proximity               float64
# dtype: object

# %%
num_rows_1_test = Offshore_Wind_new_1.shape[0]

print("Number of rows:", num_rows_1_test)
# Out:
# Number of rows: 99

# %%
Offshore_Wind_new_1.dtypes
# Out:
# New_Object_ID                 int64
# Name_Prop_x                  object
# Name_Ten                     object
# Lease_Stat                   object
# Inf_Status                   object
# Wind Speed at 100M          float64
# Wind Speed at 150M          float64
# Region                       object
# Commissioning                object
# Foundation Type              object
# Sea Name                     object
# Area                        float64
# Capacity_MW_x               float64
# Distance from Shore (km)    float64
# Grid Connection Point        object
# SHAPE_Length                float64
# SHAPE_Area_x                float64
# geometry                     object
# mpa_proximity               float64
# mcz_proximity               float64
# dtype: object

# %%
km_values = Offshore_Wind_new_1["Distance from Shore (km)"].tolist()
print(km_values)

# %%
highest_value = Offshore_Wind_new_1["Distance from Shore (km)"].max()
print(highest_value)
# Out:
# 3702.0

# %%
km_values = Offshore_Wind_new_1["Distance from Shore (km)"].tolist()
print(km_values)
# Out:
# [15.0, 15.0, 15.0, 75.0, 95.0, 8.0, 16.0, 7.0, 64.0, 7.0, 7.0, 8.0, 85.0, 85.0, 20.0, 12.0, 36.0, 23.0, 23.0, 8.0, 32.0, 27.0, 10.0, 8.0, 5.0, 5.0, 15.0, 16.0, 27.0, 121.0, 3702.0, 36.0, 74.0, 13.0, 19.0, 19.0, 138.0, 195.0, 131.0, 131.0, 120.0, 120.0, 120.0, 43.0, 33.0, 57.0, 89.0, 89.0, 72.0, 32.0, 106.0, 35.0, 37.0, 175.0, 225.0, 13.0, 13.0, 118.0, 100.0, 54.0, 28.0, 30.0, 36.0, 475.0, 73.0, 475.0, 89.0, 110.0, 110.0, 120.0, 15.0, 135.0, 24.0, 750.0, 75.0, 380.0, 150.0, 220.0, 155.0, 270.0, 270.0, 440.0, 840.0, 750.0, 1300.0, 550.0, 510.0, 750.0, 230.0, 1000.0, 330.0, 50.0, 400.0, 670.0, 350.0, 250.0, 400.0, 225.0, 600.0]

# %%
# Remove rows where the "Name" column has the value '3702.0' - removing a significant outlier
value_to_remove = 3702.0
Offshore_Wind_new_2 = Offshore_Wind_new_1[Offshore_Wind_new_1["Distance from Shore (km)"] != value_to_remove]

print(Offshore_Wind_new_2)
# Out:
#     New_Object_ID                   Name_Prop_x  \
# 0               1                      Walney 2
# 1               2                      Walney 1
# 2               3          West of Duddon Sands
# 3               4                        Barrow
# 4               5                       Ormonde
# ..            ...                           ...
# 95            110                     Havbredey
# 96            111      West of Orkney Wind Farm
# 97            112  Caledonia Offshore Wind Farm
# 98            116                    Moray West
# 99            117                        Morven
#
#                                              Name_Ten  \
# 0              Walney (UK) Offshore Windfarms Limited
# 1              Walney (UK) Offshore Windfarms Limited
# 2   ScottishPower Renewables (WoDS) Limited and Or...
# 3                        Barrow Offshore Wind Limited
# 4                              Ormonde Energy Limited
# ..                                                ...
# 95                           Northland Mhairi Limited
# 96                        Offshore Wind Power Limited
# 97                       Caledonia Offshore Wind Farm
# 98                     Moray Offshore Windfarm (West)
# 99                       Morven Offshore Wind Limited
#
#                     Lease_Stat          Inf_Status  Wind Speed at 100M  \
# 0               Lease - Marine         Operational            9.762180
# 1               Lease - Marine         Operational            9.704449
# 2               Lease - Marine         Operational            9.724218
# 3               Lease - Marine         Operational            9.563191
# 4               Lease - Marine         Operational            9.592508
# ..                         ...                 ...                 ...
# 95  Agreement/Option for Lease        Pre Planning           10.750627
# 96  Agreement/Option for Lease        Pre Planning           10.554087
# 97  Agreement/Option for Lease        Pre Planning           10.247252
# 98                Lease Marine  Under Construction            9.896408
# 99  Agreement/Option for Lease        Pre Planning           10.340673
#
#     Wind Speed at 150M         Region Commissioning  \
# 0            10.164155     Cumberland    07/12/2021
# 1            10.119843     Cumberland    14/06/2012
# 2            10.126616     Cumberland    30/10/2014
# 3            10.030605     Cumberland    22/09/2006
# 4            10.037252     Cumberland    22/02/2012
# ..                 ...            ...           ...
# 95           11.075903     Sutherland    01/01/2036
# 96           10.868001  Caithnesshire           NaN
# 97           10.544492      Caledonia           NaN
# 98           10.228200  Caithnesshire    01/01/2025
# 99           10.717812  Aberdeenshire    01/01/2030
#
#                Foundation Type              Sea Name         Area  \
# 0           Grounded: Monopile             Irish Sea   18716494.0
# 1           Grounded: Monopile             Irish Sea    2715618.0
# 2           Grounded: Monopile             Irish Sea   66889246.0
# 3           Grounded: Monopile             Irish Sea    9990135.0
# 4               Jacket (Piled)             Irish Sea     993175.0
# ..                         ...                   ...          ...
# 95     Floating: Not Specified  North Atlantic Ocean  401296145.0
# 96  Mixed (Fixed and Floating)  North Atlantic Ocean  663159908.0
# 97  Mixed (Fixed and Floating)             North Sea  428044433.0
# 98          Grounded: Monopile             North Sea  226294556.0
# 99     Grounded: Not Specified             North Sea  858539631.0
#
#     Capacity_MW_x  Distance from Shore (km) Grid Connection Point  \
# 0           183.6                      15.0             Cleveleys
# 1           183.6                      15.0             Cleveleys
# 2           389.0                      15.0               Heysham
# 3            90.0                      75.0               Heysham
# 4           150.0                      95.0               Heysham
# ..            ...                       ...                   ...
# 95         1500.0                     350.0                   NaN
# 96         2000.0                     250.0               Spittal
# 97         1000.0                     400.0              New Deer
# 98          882.0                     225.0          Blackhillock
# 99         2907.0                     600.0                 SWE1a
#
#     SHAPE_Length  SHAPE_Area_x  \
# 0       0.333629      0.006297
# 1       0.278588      0.003724
# 2       0.411103      0.009159
# 3       0.163415      0.001368
# 4       0.164165      0.001364
# ..           ...           ...
# 95      1.407979      0.060663
# 96      1.570481      0.102300
# 97      1.201315      0.065488
# 98      0.939659      0.034284
# 99      1.792705      0.125760
#
#                                              geometry  mpa_proximity  \
# 0   POLYGON ((-705942.9946688032 6152116.419927733...       0.000000
# 1   POLYGON ((-701457.1220475058 6145627.040104053...       0.000000
# 2   POLYGON ((-698911.6075414268 6138268.918918209...       0.000000
# 3   POLYGON ((-690771.6241631769 6137881.406813042...       0.000000
# 4   POLYGON ((-697020.0412259202 6150781.322604385...       0.000000
# ..                                                ...            ...
# 95  POLYGON ((-663950.69910929 6697373.180312623, ...    4908.721159
# 96  POLYGON ((-616067.2891587466 6680616.114598731...   11566.156389
# 97  POLYGON ((-522658.4720782874 6562916.557632401...   87266.560364
# 98  POLYGON ((-543381.8084593244 6581576.295733046...   94953.924814
# 99  POLYGON ((-464021.9256135698 6366169.058139542...      40.775025
#
#     mcz_proximity
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3     4615.103852
# 4        0.000000
# ..            ...
# 95   20109.702353
# 96   11566.154542
# 97   13676.737471
# 98   16066.470153
# 99      40.777638
#
# [98 rows x 20 columns]

# %%
km_values_2 = Offshore_Wind_new_2["Distance from Shore (km)"].tolist()
print(km_values_2)
# Out:
# [15.0, 15.0, 15.0, 75.0, 95.0, 8.0, 16.0, 7.0, 64.0, 7.0, 7.0, 8.0, 85.0, 85.0, 20.0, 12.0, 36.0, 23.0, 23.0, 8.0, 32.0, 27.0, 10.0, 8.0, 5.0, 5.0, 15.0, 16.0, 27.0, 121.0, 36.0, 74.0, 13.0, 19.0, 19.0, 138.0, 195.0, 131.0, 131.0, 120.0, 120.0, 120.0, 43.0, 33.0, 57.0, 89.0, 89.0, 72.0, 32.0, 106.0, 35.0, 37.0, 175.0, 225.0, 13.0, 13.0, 118.0, 100.0, 54.0, 28.0, 30.0, 36.0, 475.0, 73.0, 475.0, 89.0, 110.0, 110.0, 120.0, 15.0, 135.0, 24.0, 750.0, 75.0, 380.0, 150.0, 220.0, 155.0, 270.0, 270.0, 440.0, 840.0, 750.0, 1300.0, 550.0, 510.0, 750.0, 230.0, 1000.0, 330.0, 50.0, 400.0, 670.0, 350.0, 250.0, 400.0, 225.0, 600.0]

# %%
num_rows_2_test = Offshore_Wind_new_2.shape[0]

print("Number of rows:", num_rows_2_test)
# Out:
# Number of rows: 98

# %%
# having done final data preparation - now discussion of the results

# First Linear regression between Wind Speed and the proximity to MPZ

# %%
X_Wind_speed = Offshore_Wind_new_2['Wind Speed at 150M']  # Independent variable
y_linear_regression = Offshore_Wind_new_2['mcz_proximity']  # Dependent variable

# %%
# Fit our linear regression model
X_Wind_speed = sm.add_constant(X_Wind_speed)  
model_windspeed = sm.OLS(y_linear_regression, X_Wind_speed).fit()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
print(model_windspeed.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          mcz_proximity   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.8802
# Date:                Sun, 17 Sep 2023   Prob (F-statistic):              0.350
# Time:                        15:12:33   Log-Likelihood:                -1114.0
# No. Observations:                  98   AIC:                             2232.
# Df Residuals:                      96   BIC:                             2237.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -3.789e+04    6.3e+04     -0.602      0.549   -1.63e+05    8.71e+04
# Wind Speed at 150M  5769.3044   6149.345      0.938      0.350   -6437.050     1.8e+04
# ==============================================================================
# Omnibus:                       17.709   Durbin-Watson:                   1.327
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.987
# Skew:                           1.101   Prob(JB):                     2.77e-05
# Kurtosis:                       3.535   Cond. No.                         305.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# coefficients <3
intercept, slope = model_windspeed.params['const'], model_windspeed.params['Wind Speed at 150M']

# Create scatterplot with regression line
plt.scatter(Offshore_Wind_new_2['Wind Speed at 150M'], Offshore_Wind_new_2['mcz_proximity'], label='Data')
plt.plot(Offshore_Wind_new_2['Wind Speed at 150M'], intercept + slope * Offshore_Wind_new_2['Wind Speed at 150M'], color='red', label='Regression Line')
plt.xlabel('Wind Speed at 150M')
plt.ylabel('mcz_proximity')
plt.legend()
plt.title('Linear Regression: Wind Speed vs. Proximity to Marine Protected Zones')
plt.show()

# %%
# Linear regression between Capacity and the proximity to MPZ

# %%
X_Capacity = Offshore_Wind_new_2['Capacity_MW_x']

# %%
# Fit the linear regression model
X_Capacity = sm.add_constant(X_Capacity)  
model_capacity = sm.OLS(y_linear_regression, X_Capacity).fit()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
print(model_capacity.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          mcz_proximity   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     5.754
# Date:                Sun, 17 Sep 2023   Prob (F-statistic):             0.0184
# Time:                        15:13:28   Log-Likelihood:                -1111.6
# No. Observations:                  98   AIC:                             2227.
# Df Residuals:                      96   BIC:                             2232.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.597e+04   2999.996      5.325      0.000       1e+04    2.19e+04
# Capacity_MW_x     7.1264      2.971      2.399      0.018       1.229      13.024
# ==============================================================================
# Omnibus:                       10.065   Durbin-Watson:                   1.432
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               10.690
# Skew:                           0.808   Prob(JB):                      0.00477
# Kurtosis:                       3.082   Cond. No.                     1.45e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#  Get our regression coefficients
intercept, slope = model_capacity.params['const'], model_capacity.params['Capacity_MW_x']

# Create scatterplot with regression line
plt.scatter(Offshore_Wind_new_2['Capacity_MW_x'], Offshore_Wind_new_2['mcz_proximity'], label='Data')
plt.plot(Offshore_Wind_new_2['Capacity_MW_x'], intercept + slope * Offshore_Wind_new_2['Capacity_MW_x'], color='red', label='Regression Line')
plt.xlabel('Capacity_MW_x')
plt.ylabel('mcz_proximity')
plt.legend()
plt.title('Linear Regression: Capacity MW vs. Proximity to Marine Protected Zones')
plt.show()

# %%
# Linear regression between Distance to Shore and the proximity to MPZ

# %%
X_Distance = Offshore_Wind_new_2['Distance from Shore (km)']  # Independent variable

# %%
# Fit the linear regression model
X_Distance = sm.add_constant(X_Distance)
model_distance = sm.OLS(y_linear_regression, X_Distance).fit()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
print(model_distance.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          mcz_proximity   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     2.915
# Date:                Sun, 17 Sep 2023   Prob (F-statistic):             0.0910
# Time:                        15:18:36   Log-Likelihood:                -1112.9
# No. Observations:                  98   AIC:                             2230.
# Df Residuals:                      96   BIC:                             2235.
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     1.857e+04   2597.723      7.150      0.000    1.34e+04    2.37e+04
# Distance from Shore (km)    14.9435      8.753      1.707      0.091      -2.431      32.318
# ==============================================================================
# Omnibus:                       16.697   Durbin-Watson:                   1.338
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.369
# Skew:                           1.057   Prob(JB):                     6.22e-05
# Kurtosis:                       3.528   Cond. No.                         365.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#  Get our regression coefficients
intercept, slope = model_distance.params['const'], model_distance.params['Distance from Shore (km)']

# Create scatterplot with regression line
plt.scatter(Offshore_Wind_new_2['Distance from Shore (km)'], Offshore_Wind_new_2['mcz_proximity'], label='Data')
plt.plot(Offshore_Wind_new_2['Distance from Shore (km)'], intercept + slope * Offshore_Wind_new_2['Distance from Shore (km)'], color='red', label='Regression Line')
plt.xlabel('Distance from Shore (km)')
plt.ylabel('mcz_proximity')
plt.legend()
plt.title('Linear Regression: Distance From Shore KM vs. Proximity to Marine Protected Zones')
plt.show()

# %%
# MULTIPLE LINEAR REGRESSION:

# %%
# Define the predictor variables (independent variables)
Independent_VAR = ['Wind Speed at 150M', 'Distance from Shore (km)', 'Capacity_MW_x']

# %%
# Add a constant term to the predictor variables
X_ML = sm.add_constant(Offshore_Wind_new_2[Independent_VAR])

# %%
# Define the dependent variable
y_ML = Offshore_Wind_new_2['mcz_proximity']

# %%
test_model_final = sm.OLS(y_ML, X_ML).fit()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
print(test_model_final.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          mcz_proximity   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     2.082
# Date:                Sun, 17 Sep 2023   Prob (F-statistic):              0.108
# Time:                        18:02:18   Log-Likelihood:                -1111.3
# No. Observations:                  98   AIC:                             2231.
# Df Residuals:                      94   BIC:                             2241.
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     4.735e+04    7.4e+04      0.640      0.524   -9.95e+04    1.94e+05
# Wind Speed at 150M       -3155.8409   7358.370     -0.429      0.669   -1.78e+04    1.15e+04
# Distance from Shore (km)     8.0323     10.796      0.744      0.459     -13.403      29.467
# Capacity_MW_x                6.4841      3.576      1.813      0.073      -0.616      13.584
# ==============================================================================
# Omnibus:                       10.292   Durbin-Watson:                   1.425
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               10.964
# Skew:                           0.818   Prob(JB):                      0.00416
# Kurtosis:                       3.093   Cond. No.                     3.65e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.65e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Calculate VIF for each independent variable
vif = pd.DataFrame()
vif["Variable"] = X_ML.columns
vif["VIF"] = [variance_inflation_factor(X_ML.values, i) for i in range(X.shape[1])]

# Display the VIF values
print(vif)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                    Variable          VIF
# 0                     const  1242.523513
# 1        Wind Speed at 150M     1.481641
# 2  Distance from Shore (km)     1.541714
# 3             Capacity_MW_x     1.427192

# %%
# Polynomial Regression -

# %%
from sklearn.preprocessing import PolynomialFeatures  # Import PolynomialFeatures

# %%
# Polynomial regression with multiple predictors 
X_P = Offshore_Wind_new_2[['Wind Speed at 150M', 'Distance from Shore (km)', 'Capacity_MW_x']]
X_P = sm.add_constant(X_P)  # Add a constant
y_P = Offshore_Wind_new_2['mcz_proximity']

# Define the degree of the polynomial
degree = 2  

# Create polynomial features
poly = PolynomialFeatures(degree=degree)
X_poly = poly.fit_transform(X_P)

# Fit the multiple polynomial regression model
model = sm.OLS(y_P, X_poly).fit()

print(model.summary())
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          mcz_proximity   R-squared:                       0.212
# Model:                            OLS   Adj. R-squared:                  0.132
# Method:                 Least Squares   F-statistic:                     2.634
# Date:                Sun, 17 Sep 2023   Prob (F-statistic):            0.00953
# Time:                        15:28:29   Log-Likelihood:                -1102.7
# No. Observations:                  98   AIC:                             2225.
# Df Residuals:                      88   BIC:                             2251.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.154e+05   5.51e+05      1.479      0.143    -2.8e+05    1.91e+06
# x1          8.154e+05   5.51e+05      1.479      0.143    -2.8e+05    1.91e+06
# x2          -2.49e+05   1.65e+05     -1.509      0.135   -5.77e+05    7.89e+04
# x3           382.9412    288.402      1.328      0.188    -190.197     956.079
# x4           140.7061     74.011      1.901      0.061      -6.375     287.787
# x5          8.154e+05   5.51e+05      1.479      0.143    -2.8e+05    1.91e+06
# x6          -2.49e+05   1.65e+05     -1.509      0.135   -5.77e+05    7.89e+04
# x7           382.9460    288.403      1.328      0.188    -190.194     956.086
# x8           140.7061     74.011      1.901      0.061      -6.375     287.787
# x9          2.542e+04   1.65e+04      1.544      0.126   -7301.959    5.81e+04
# x10          -76.7191     55.828     -1.374      0.173    -187.665      34.227
# x11          -25.2075     14.646     -1.721      0.089     -54.313       3.898
# x12            0.0230      0.029      0.782      0.436      -0.035       0.082
# x13            0.0294      0.015      1.907      0.060      -0.001       0.060
# x14           -0.0090      0.004     -2.155      0.034      -0.017      -0.001
# ==============================================================================
# Omnibus:                        8.091   Durbin-Watson:                   1.574
# Prob(Omnibus):                  0.018   Jarque-Bera (JB):                8.327
# Skew:                           0.714   Prob(JB):                       0.0156
# Kurtosis:                       3.011   Cond. No.                     8.19e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.46e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Calculate VIF for each independent variable
vif_2 = pd.DataFrame()
vif_2["Variable"] = X_P.columns
vif_2["VIF"] = [variance_inflation_factor(X_P.values, i) for i in range(X_P.shape[1])]

# Display the VIF values
print(vif)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                    Variable          VIF
# 0                     const  1242.523513
# 1        Wind Speed at 150M     1.481641
# 2  Distance from Shore (km)     1.541714
# 3             Capacity_MW_x     1.427192
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
